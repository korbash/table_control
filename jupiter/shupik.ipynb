# %%
import korbash_lib as kb
import pandas as pd
import matplotlib
from bokeh.io import push_notebook, show, output_notebook
output_notebook()
# Out:
# Connected to Motor Controller Model 8742. Firmware Version 3.04 09/09/16
#
# Motor #1: No motor connected
# Motor #2: No motor connected
# Motor #3: No motor connected
# Motor #4: No motor connected
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
tk=kb.Tikalka(simulate=True)
kb.Time.SetZeroTime()
kb.Time.freez()

# %%
data=kb.DataBase()

# %%
print(tk.tg.ReadValue(DataB=data))
tk.FindZero(zapas=2000)
print(tk.tg.ReadValue(DataB=data))
# Out:
# 0.00014617977568432154
# 0.00025303970077474286

# %%
shDat=tk.Shup(0.1)

# %%
shDat.plot(x='time',y='tension')
# Out:
# <AxesSubplot:xlabel='time'>

# %%
from visualization import PlotDisplayer

# %%
pl=PlotDisplayer()
pl.CreateMaket(mainParam='time',tension=shDat[['time','tension']])
pl.Show()
# Out:
#   <div class="bk-root" id="d2be1c23-9426-4127-8277-99ee42b55b26" data-root-id="1088"></div>
